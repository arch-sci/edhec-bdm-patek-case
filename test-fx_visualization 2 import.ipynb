# %%
import os
os.environ["GCP_PROJECT_ID"] = "projectbdm-487109"

# 1. Import our own code
from patek_analysis.data import get_patek_data
from patek_analysis.fx_rates import fx_rate
import matplotlib.pyplot as plt

# 2. Use the function to get the dataframe
df = get_patek_data() 

# 3. Now we can analyze 'df' using Matplotlib/Seaborn
df_filtered = df[df['price'] <= 1000000]

## Draw price frequency on matplotlib :
plt.grid(True, alpha =0.3)
plt.hist(df_filtered['price'], bins=20, color='red', edgecolor='black')
plt.xlabel('Price in euros')
plt.ylabel('Occurrences')
plt.title('Histogram of Price by Occurrences')
plt.ticklabel_format(style='plain', axis='x')
plt.show()
# Out:
# /usr/local/lib/python3.10/site-packages/google/api_core/_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 1. Import our own code
#       2 from patek_analysis.data import get_patek_data
# ----> 3 from patek_analysis.fx_rates import fx_rate
#       5 # 2. Use the function to get the dataframe
#       6 df = get_patek_data()
#
# File /usr/local/lib/python3.10/site-packages/patek_analysis/fx_rates.py:18
# ...
